# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('2020-07.csv', encoding='latin-1', error_bad_lines=False)
# Out:
# b'Skipping line 6: expected 4 fields, saw 5\nSkipping line 11: expected 4 fields, saw 5\nSkipping line 13: expected 4 fields, saw 9\nSkipping line 20: expected 4 fields, saw 9\nSkipping line 27: expected 4 fields, saw 5\nSkipping line 28: expected 4 fields, saw 9\nSkipping line 32: expected 4 fields, saw 5\nSkipping line 41: expected 4 fields, saw 5\nSkipping line 42: expected 4 fields, saw 6\nSkipping line 43: expected 4 fields, saw 5\nSkipping line 60: expected 4 fields, saw 7\nSkipping line 62: expected 4 fields, saw 5\nSkipping line 83: expected 4 fields, saw 5\nSkipping line 84: expected 4 fields, saw 5\nSkipping line 88: expected 4 fields, saw 5\nSkipping line 89: expected 4 fields, saw 5\nSkipping line 92: expected 4 fields, saw 6\nSkipping line 95: expected 4 fields, saw 9\nSkipping line 99: expected 4 fields, saw 5\nSkipping line 103: expected 4 fields, saw 9\nSkipping line 109: expected 4 fields, saw 7\nSkipping line 110: expected 4 fields, saw 5\nSkipping line 112: expected 4 fields, saw 5\nSkipping line 122: expected 4 fields, saw 9\nSkipping line 123: expected 4 fields, saw 5\nSkipping line 124: expected 4 fields, saw 8\nSkipping line 127: expected 4 fields, saw 5\nSkipping line 128: expected 4 fields, saw 5\nSkipping line 133: expected 4 fields, saw 5\nSkipping line 137: expected 4 fields, saw 5\nSkipping line 154: expected 4 fields, saw 10\nSkipping line 169: expected 4 fields, saw 5\nSkipping line 171: expected 4 fields, saw 5\nSkipping line 174: expected 4 fields, saw 7\nSkipping line 176: expected 4 fields, saw 9\nSkipping line 181: expected 4 fields, saw 5\nSkipping line 183: expected 4 fields, saw 9\nSkipping line 187: expected 4 fields, saw 7\nSkipping line 190: expected 4 fields, saw 9\nSkipping line 204: expected 4 fields, saw 9\nSkipping line 209: expected 4 fields, saw 5\nSkipping line 216: expected 4 fields, saw 5\nSkipping line 222: expected 4 fields, saw 8\nSkipping line 225: expected 4 fields, saw 9\nSkipping line 228: expected 4 fields, saw 7\nSkipping line 237: expected 4 fields, saw 7\nSkipping line 238: expected 4 fields, saw 7\nSkipping line 243: expected 4 fields, saw 8\nSkipping line 247: expected 4 fields, saw 7\nSkipping line 256: expected 4 fields, saw 6\nSkipping line 257: expected 4 fields, saw 8\nSkipping line 260: expected 4 fields, saw 5\nSkipping line 261: expected 4 fields, saw 9\nSkipping line 278: expected 4 fields, saw 7\nSkipping line 286: expected 4 fields, saw 7\nSkipping line 288: expected 4 fields, saw 5\nSkipping line 289: expected 4 fields, saw 7\nSkipping line 290: expected 4 fields, saw 5\nSkipping line 291: expected 4 fields, saw 7\nSkipping line 293: expected 4 fields, saw 5\nSkipping line 294: expected 4 fields, saw 9\nSkipping line 296: expected 4 fields, saw 5\nSkipping line 301: expected 4 fields, saw 9\nSkipping line 306: expected 4 fields, saw 5\nSkipping line 310: expected 4 fields, saw 6\nSkipping line 313: expected 4 fields, saw 8\nSkipping line 314: expected 4 fields, saw 9\nSkipping line 319: expected 4 fields, saw 7\nSkipping line 320: expected 4 fields, saw 6\nSkipping line 325: expected 4 fields, saw 6\nSkipping line 327: expected 4 fields, saw 9\nSkipping line 329: expected 4 fields, saw 5\nSkipping line 330: expected 4 fields, saw 8\nSkipping line 331: expected 4 fields, saw 5\nSkipping line 334: expected 4 fields, saw 8\nSkipping line 346: expected 4 fields, saw 9\nSkipping line 349: expected 4 fields, saw 9\nSkipping line 352: expected 4 fields, saw 8\nSkipping line 354: expected 4 fields, saw 8\nSkipping line 361: expected 4 fields, saw 6\nSkipping line 367: expected 4 fields, saw 7\nSkipping line 371: expected 4 fields, saw 9\nSkipping line 378: expected 4 fields, saw 9\nSkipping line 382: expected 4 fields, saw 5\nSkipping line 386: expected 4 fields, saw 8\nSkipping line 398: expected 4 fields, saw 5\nSkipping line 405: expected 4 fields, saw 8\nSkipping line 409: expected 4 fields, saw 8\nSkipping line 423: expected 4 fields, saw 5\nSkipping lin ...

# %%
data
# Out:
#                                                                                                                                                          Região;UF;Cidade;Sexo;Faixa Etária;Data Finalização;Tempo Resposta;Nome Fantasia;Segmento de Mercado;Área;Assunto;Grupo Problema;Problema;Como Comprou Contratou;Procurou Empresa;Respondida;Situação;Avaliação Reclamação;Nota do Consumidor;Total
# S ;RS;Gua?ba;F;entre 61 a 70 anos;01/07/2020;15...  Financeiras e Administradoras de Cartão;Serviç...  pagamentos                                          saldo devedor;Loja física;S;S;Finalizada não ...
# S ;RS;Gua?ba;F;entre 51 a 60 anos;02/07/2020;15...  Financeiras e Administradoras de Cartão;Serviç...  pagamentos                                          saldo devedor;Telefone;S;S;Finalizada não ava...
# S ;RS;São Leopoldo;F;mais de 70 anos;02/07/2020...  Financeiras e Administradoras de Cartão;Serviç... NaN                                                                                               NaN
# NE;CE;Trairi;M;entre 31 a 40 anos;02/07/2020;15...  Financeiras e Administradoras de Cartão;Serviç... NaN                                                                                               NaN
# NE;PE;São Lourenço da Mata;M;entre 31 a 40 anos...  Internet                                           TV por assinatura);Telecomunicações;Telefonia ...                                                NaN
# ...                                                                                                                                                                                                     ...
# NE;CE;Fortaleza;M;entre 31 a 40 anos;31/07/2020...  Financeiras e Administradoras de Cartão;Serviç... NaN                                                                                               NaN
# CO;MT;Cuiabá;M;entre 21 a 30 anos;31/07/2020;0;...  Energia                                            Gás;Energia Elétrica;Cobrança / Contestação;Co...                                                NaN
# CO;MT;Primavera do Leste;M;entre 21 a 30 anos;3...  Energia                                            Gás;Energia Elétrica;Contrato / Oferta;Dificul...                                                NaN
# SE;RJ;São Gonçalo;M;entre 51 a 60 anos;31/07/20...  Internet                                           TV por assinatura);Telecomunicações;TV por Ass...                                                NaN
# S ;PR;Colombo;M;entre 21 a 30 anos;31/07/2020;0...  Financeiras e Administradoras de Cartão;Serviç...  taxas                                               valores não previstos / não informados;Telefo...
#
# [95017 rows x 1 columns]

# %%
data2=pd.read_csv('2020-07.csv', sep=';', encoding='latin-1')

# %%
data2
# Out:
#        Região  UF        Cidade Sexo        Faixa Etária Data Finalização  \
# 0          S   RS        Gua?ba    F  entre 61 a 70 anos       01/07/2020
# 1          S   RS        Gua?ba    F  entre 51 a 60 anos       02/07/2020
# 2          S   RS  São Leopoldo    F     mais de 70 anos       02/07/2020
# 3          NE  CE        Trairi    M  entre 31 a 40 anos       02/07/2020
# 4          NE  PE        Recife    M  entre 31 a 40 anos       01/07/2020
# ...       ...  ..           ...  ...                 ...              ...
# 122546     NE  CE     Maracanaú    F  entre 31 a 40 anos       31/07/2020
# 122547     N   AM        Manaus    M  entre 21 a 30 anos       31/07/2020
# 122548     SE  SP    Cosm?polis    F  entre 21 a 30 anos       31/07/2020
# 122549     SE  RJ   São Gonçalo    M  entre 51 a 60 anos       31/07/2020
# 122550     S   PR       Colombo    M  entre 21 a 30 anos       31/07/2020
#
#         Tempo Resposta             Nome Fantasia  \
# 0                   15  Itaú Unibanco Consignado
# 1                   15  Itaú Unibanco Consignado
# 2                   15           Itaú Consignado
# 3                   15           Banco Santander
# 4                    0            Casasbahia.com
# ...                ...                       ...
# 122546               0          Serasa Experian
# 122547               0          Serasa Experian
# 122548               0                  Ipiranga
# 122549               0                       SKY
# 122550               0                  Itaucard
#
#                                       Segmento de Mercado  \
# 0         Bancos, Financeiras e Administradoras de Cartão
# 1         Bancos, Financeiras e Administradoras de Cartão
# 2         Bancos, Financeiras e Administradoras de Cartão
# 3         Bancos, Financeiras e Administradoras de Cartão
# 4                                     Comércio Eletrônico
# ...                                                   ...
# 122546        Bancos de Dados e Cadastros de Consumidores
# 122547        Bancos de Dados e Cadastros de Consumidores
# 122548               Distribuidoras de Combustíveis / Gás
# 122549  Operadoras de Telecomunicações (Telefonia, Int...
# 122550    Bancos, Financeiras e Administradoras de Cartão
#
#                                            Área  \
# 0                          Serviços Financeiros
# 1                          Serviços Financeiros
# 2                          Serviços Financeiros
# 3                          Serviços Financeiros
# 4       Produtos Eletrodomésticos e Eletrônicos
# ...                                         ...
# 122546                     Serviços Financeiros
# 122547                     Serviços Financeiros
# 122548                          Demais Produtos
# 122549                         Telecomunicações
# 122550                     Serviços Financeiros
#
#                                                   Assunto  \
# 0       Crédito Consignado / Cartão de Crédito Consign...
# 1       Crédito Consignado / Cartão de Crédito Consign...
# 2       Crédito Consignado (para servidores públicos o...
# 3       Cartão de Crédito / Cartão de Débito / Cartão ...
# 4       Eletroportáteis ( batedeira, liquidificador, u...
# ...                                                   ...
# 122546  Banco de Dados e Cadastros de Consumidores (SP...
# 122547  Banco de Dados e Cadastros de Consumidores (SP...
# 122548  Combustível / Inflamáveis (gasolina, etanol, ó...
# 122549                                  TV por Assinatura
# 122550  Cartão de Crédito / Cartão de Débito / Cartão ...
#
#                 Grupo Problema  \
# 0       Cobrança / Contestação
# 1       Cobrança / Contestação
# 2            Atendimento / SAC
# 3           Vício de Qualidade
# 4       Cobrança / Contestação
# ...                        ...
# 122546              Informação
# 122547              Informação
# 122548       Saúde e Segurança
# 122549  Cobrança / Contestação
# 122550  Cobrança / Contestação
#
#                                                  Problema  \
# 0       Dificuldade para obter boleto de quitação ou i...
# 1       Dificuldade para obter boleto de quitação ou i...
# 2       Má qualidade no atendimento presencial ou outr...
# 3               Dificuldade para alterar/ ativar serviços
# 4       Dificuldade / atraso na devolução de valores p...
# ...                                                   ...
# 122546  Dados pessoais ou financeiros consultados, col...
# 122547  Dados pessoais ou financeiros consultados, col...
# 122548  Alteração de odor, sabor, aspecto ou composiçã...
# 122549  Cobrança por serviço/produto não contratado / ...
# 122550  Cobrança de tarifas, taxas, valores não previs...
#
#          Como Comprou Contratou Procurou Empresa Respondida  \
# 0                   Loja física                S          S
# 1                      Telefone                S          S
# 2                   Loja física                S          S
# 3       Não comprei / contratei                S          S
# 4                      Internet                S          N
# ...                         ...              ...        ...
# 122546                 Internet                N          S
# 122547                 Internet                N          S
# 122548              Loja física                N          S
# 122549                 Telefone                S          S
# 122550                 Telefone                S          S
#
#                        Situação Avaliação Reclamação  Nota do Consumidor  \
# 0       Finalizada não avaliada         Não Avaliada                   0
# 1       Finalizada não avaliada         Não Avaliada                   0
# 2       Finalizada não avaliada         Não Avaliada                   0
# 3           Finalizada avaliada        Não Resolvida                   1
# 4           Finalizada avaliada            Resolvida                   3
# ...                         ...                  ...                 ...
# 122546      Finalizada avaliada            Resolvida                   5
# 122547      Finalizada avaliada        Não Resolvida                   1
# 122548      Finalizada avaliada        Não Resolvida                   3
# 122549      Finalizada avaliada            Resolvida                   5
# 122550      Finalizada avaliada            Resolvida                   4
#
#         Total
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 122546      1
# 122547      1
# 122548      1
# 122549      1
# 122550      1
#
# [122551 rows x 20 columns]

# %%
data3=pd.read_csv('2020-05.csv', sep=';', encoding='latin-1')

# %%
data3
# Out:
#       Região  UF          Cidade Sexo        Faixa Etária Data Finalização  \
# 0         CO  DF        Brasília    F  entre 31 a 40 anos       01/05/2020
# 1         SE  RJ         Niterói    M  entre 41 a 50 anos       04/05/2020
# 2         S   RS     Santa Maria    M  entre 41 a 50 anos       02/05/2020
# 3         NE  RN           Natal    F  entre 31 a 40 anos       05/05/2020
# 4         SE  RJ  Rio de Janeiro    F  entre 41 a 50 anos       04/05/2020
# ...      ...  ..             ...  ...                 ...              ...
# 93896     SE  SP       São Paulo    F  entre 61 a 70 anos       31/05/2020
# 93897     SE  SP       São Paulo    M  entre 21 a 30 anos       31/05/2020
# 93898     SE  SP       São Paulo    M  entre 21 a 30 anos       31/05/2020
# 93899     SE  SP       São Paulo    M  entre 21 a 30 anos       31/05/2020
# 93900     SE  SP       São Paulo    F  entre 31 a 40 anos       31/05/2020
#
#        Tempo Resposta            Nome Fantasia  \
# 0                 NaN          Flytour Viagens
# 1                15.0                Submarino
# 2                15.0  Vivo - Telefônica (GVT)
# 3                15.0  Banco Santander Cartões
# 4                15.0           Americanas.com
# ...               ...                      ...
# 93896             0.0                      SKY
# 93897             0.0                      SKY
# 93898             0.0                      SKY
# 93899             0.0                      SKY
# 93900             0.0                      SKY
#
#                                      Segmento de Mercado  \
# 0          Viagens, Turismo, Hospedagem e Entretenimento
# 1                                    Comércio Eletrônico
# 2      Operadoras de Telecomunicações (Telefonia, Int...
# 3        Bancos, Financeiras e Administradoras de Cartão
# 4                                    Comércio Eletrônico
# ...                                                  ...
# 93896  Operadoras de Telecomunicações (Telefonia, Int...
# 93897  Operadoras de Telecomunicações (Telefonia, Int...
# 93898  Operadoras de Telecomunicações (Telefonia, Int...
# 93899  Operadoras de Telecomunicações (Telefonia, Int...
# 93900  Operadoras de Telecomunicações (Telefonia, Int...
#
#                                           Área  \
# 0                              Turismo/Viagens
# 1                              Demais Produtos
# 2                             Telecomunicações
# 3                         Serviços Financeiros
# 4      Produtos Eletrodomésticos e Eletrônicos
# ...                                        ...
# 93896                         Telecomunicações
# 93897                         Telecomunicações
# 93898                         Telecomunicações
# 93899                         Telecomunicações
# 93900                         Telecomunicações
#
#                                                  Assunto  \
# 0                 Pacote / excursão / agência de turismo
# 1       Material de construção, acabamento e ferramentas
# 2                                          Internet Fixa
# 3      Cartão de Crédito / Cartão de Débito / Cartão ...
# 4                Ar condicionado, ventilador e aquecedor
# ...                                                  ...
# 93896                                  TV por Assinatura
# 93897                                  TV por Assinatura
# 93898                                  TV por Assinatura
# 93899                                  TV por Assinatura
# 93900                                  TV por Assinatura
#
#                Grupo Problema  \
# 0      Cobrança / Contestação
# 1          Entrega do Produto
# 2           Contrato / Oferta
# 3      Cobrança / Contestação
# 4           Contrato / Oferta
# ...                       ...
# 93896  Cobrança / Contestação
# 93897  Cobrança / Contestação
# 93898  Cobrança / Contestação
# 93899  Cobrança / Contestação
# 93900  Cobrança / Contestação
#
#                                                 Problema  \
# 0      Dificuldade / atraso na devolução de valores p...
# 1      Produto entregue incompleto / diferente do  pe...
# 2      Oferta não cumprida / serviço não fornecido/ v...
# 3      Cálculo de juros, saldo devedor (contestação, ...
# 4      Oferta não cumprida / serviço não fornecido/ v...
# ...                                                  ...
# 93896              Cobrança após cancelamento do serviço
# 93897              Cobrança após cancelamento do serviço
# 93898              Cobrança após cancelamento do serviço
# 93899              Cobrança após cancelamento do serviço
# 93900              Cobrança após cancelamento do serviço
#
#         Como Comprou Contratou Procurou Empresa Respondida  \
# 0      SMS / Mensagem de texto                S          N
# 1                     Internet                S          S
# 2                  Loja física                N          S
# 3                     Internet                S          S
# 4                     Internet                S          S
# ...                        ...              ...        ...
# 93896                 Telefone                N          S
# 93897                 Telefone                N          S
# 93898  Stand, feiras e eventos                N          S
# 93899  Stand, feiras e eventos                N          S
# 93900  Não comprei / contratei                N          S
#
#                       Situação Avaliação Reclamação  Nota do Consumidor  Total
# 0      Finalizada não avaliada         Não Avaliada                 NaN      1
# 1      Finalizada não avaliada         Não Avaliada                 NaN      1
# 2      Finalizada não avaliada         Não Avaliada                 NaN      1
# 3      Finalizada não avaliada         Não Avaliada                 NaN      1
# 4      Finalizada não avaliada         Não Avaliada                 NaN      1
# ...                        ...                  ...                 ...    ...
# 93896      Finalizada avaliada            Resolvida                 5.0      1
# 93897      Finalizada avaliada            Resolvida                 5.0      1
# 93898      Finalizada avaliada            Resolvida                 5.0      1
# 93899      Finalizada avaliada            Resolvida                 5.0      1
# 93900      Finalizada avaliada            Resolvida                 5.0      1
#
# [93901 rows x 20 columns]

# %%
array=['2019-0'+str(x) for x in range(1,10)]+['2019-10','2019-11','2019-12']

# %%
array
# Out:
# ['2019-01',
#  '2019-02',
#  '2019-03',
#  '2019-04',
#  '2019-05',
#  '2019-06',
#  '2019-07',
#  '2019-08',
#  '2019-09',
#  '2019-10',
#  '2019-11',
#  '2019-12']

# %%
partial=pd.read_csv('2019-01.csv', sep=';', encoding='latin-1')
for dat in array[1:]:
    caminho= dat +'.csv'
    df_ = pd.read_csv(caminho, sep=';', encoding='latin-1')
    partial= pd.concat([partial, df_])

# %%
partial
# Out:
#       Região  UF              Cidade Sexo        Faixa Etária  \
# 0         SE  RJ            Papucaia    F  entre 61 a 70 anos
# 1         SE  RJ              Japeri    M  entre 31 a 40 anos
# 2         SE  SP           São Paulo    M  entre 31 a 40 anos
# 3         SE  SP     Pindamonhangaba    M  entre 51 a 60 anos
# 4         SE  SP           São Paulo    F  entre 21 a 30 anos
# ...      ...  ..                 ...  ...                 ...
# 76766     SE  SP           São Paulo    M  entre 31 a 40 anos
# 76767     SE  SP           São Paulo    F  entre 31 a 40 anos
# 76768     SE  RJ  São João de Meriti    F  entre 61 a 70 anos
# 76769     SE  SP           Rio Claro    M  entre 21 a 30 anos
# 76770     S   PR               Turvo    F  entre 21 a 30 anos
#
#       Data Finalização  Tempo Resposta     Nome Fantasia  \
# 0           30/01/2019             3.0        Banco Pan
# 1           28/01/2019             0.0  Serasa Experian
# 2           31/01/2019             2.0           Samsung
# 3           26/01/2019             1.0               NET
# 4           24/01/2019             0.0  Serasa Experian
# ...                ...             ...               ...
# 76766       20/12/2019             3.0               Tim
# 76767       27/12/2019             3.0               Tim
# 76768       21/12/2019             2.0      Mercado Pago
# 76769       27/12/2019             7.0               Tim
# 76770       26/12/2019             2.0               Tim
#
#                                      Segmento de Mercado  \
# 0        Bancos, Financeiras e Administradoras de Cartão
# 1            Bancos de Dados e Cadastros de Consumidores
# 2      Fabricantes - Eletroeletrônicos,  Produtos de ...
# 3      Operadoras de Telecomunicações (Telefonia, Int...
# 4            Bancos de Dados e Cadastros de Consumidores
# ...                                                  ...
# 76766  Operadoras de Telecomunicações (Telefonia, Int...
# 76767  Operadoras de Telecomunicações (Telefonia, Int...
# 76768                   Empresas de Pagamento Eletrônico
# 76769  Operadoras de Telecomunicações (Telefonia, Int...
# 76770  Operadoras de Telecomunicações (Telefonia, Int...
#
#                                       Área  ...                 Situação  \
# 0                     Serviços Financeiros  ...      Finalizada avaliada
# 1                     Serviços Financeiros  ...      Finalizada avaliada
# 2      Produtos de Telefonia e Informática  ...      Finalizada avaliada
# 3                         Telecomunicações  ...      Finalizada avaliada
# 4                     Serviços Financeiros  ...      Finalizada avaliada
# ...                                    ...  ...                      ...
# 76766                     Telecomunicações  ...      Finalizada avaliada
# 76767                     Telecomunicações  ...      Finalizada avaliada
# 76768                 Serviços Financeiros  ...  Finalizada não avaliada
# 76769                     Telecomunicações  ...      Finalizada avaliada
# 76770                     Telecomunicações  ...  Finalizada não avaliada
#
#       Avaliação Reclamação Nota do Consumidor Total ï»¿RegiÃ£o Faixa EtÃ¡ria  \
# 0            Não Resolvida                1.0     1        NaN           NaN
# 1            Não Resolvida                1.0     1        NaN           NaN
# 2            Não Resolvida                1.0     1        NaN           NaN
# 3                Resolvida                5.0     1        NaN           NaN
# 4            Não Resolvida                1.0     1        NaN           NaN
# ...                    ...                ...   ...        ...           ...
# 76766        Não Resolvida                1.0     1        NaN           NaN
# 76767            Resolvida                4.0     1        NaN           NaN
# 76768         Não Avaliada                NaN     1        NaN           NaN
# 76769            Resolvida                5.0     1        NaN           NaN
# 76770         Não Avaliada                NaN     1        NaN           NaN
#
#       Data FinalizaÃ§Ã£o Ãrea  SituaÃ§Ã£o  AvaliaÃ§Ã£o ReclamaÃ§Ã£o
# 0                    NaN   NaN         NaN                       NaN
# 1                    NaN   NaN         NaN                       NaN
# 2                    NaN   NaN         NaN                       NaN
# 3                    NaN   NaN         NaN                       NaN
# 4                    NaN   NaN         NaN                       NaN
# ...                  ...   ...         ...                       ...
# 76766                NaN   NaN         NaN                       NaN
# 76767                NaN   NaN         NaN                       NaN
# 76768                NaN   NaN         NaN                       NaN
# 76769                NaN   NaN         NaN                       NaN
# 76770                NaN   NaN         NaN                       NaN
#
# [780179 rows x 26 columns]

# %%
partial['Área'].unique()
# Out:
# array(['Serviços Financeiros', 'Produtos de Telefonia e Informática',
#        'Telecomunicações', 'Demais Produtos', 'Demais Serviços ',
#        'Produtos Eletrodomésticos e Eletrônicos', 'Transportes',
#        'Água, Energia, Gás', 'Alimentos', 'Turismo/Viagens', 'Saúde',
#        'Educação', 'Habitação', nan], dtype=object)

# %%
partial['Área']=[t if t!='Produtos de Telefonia e Informática' else 'Telecomunicações' for t in partial['Área'].values]

# %%
partial['Área'].unique()
# Out:
# array(['Serviços Financeiros', 'Telecomunicações', 'Demais Produtos',
#        'Demais Serviços ', 'Produtos Eletrodomésticos e Eletrônicos',
#        'Transportes', 'Água, Energia, Gás', 'Alimentos',
#        'Turismo/Viagens', 'Saúde', 'Educação', 'Habitação', nan],
#       dtype=object)

# %%
df_tele=partial[partial['Área']=='Telecomunicações']

# %%
df_tele.reset_index(inplace=True, drop=True)

# %%
df_tele.to_csv('DadosTelecom2019_novo.csv')

# %%
df_tele
# Out:
#        Região  UF            Cidade Sexo        Faixa Etária Data Finalização  \
# 0          SE  SP         São Paulo    M  entre 31 a 40 anos       31/01/2019
# 1          SE  SP   Pindamonhangaba    M  entre 51 a 60 anos       26/01/2019
# 2          SE  SP         São Paulo    M  entre 31 a 40 anos       29/01/2019
# 3          SE  RJ         Queimados    F  entre 31 a 40 anos       31/01/2019
# 4          NE  PI          Parnaíba    M  entre 21 a 30 anos       24/01/2019
# ...       ...  ..               ...  ...                 ...              ...
# 182872     S   PR  São José do Ivaí    F         até 20 anos       24/12/2019
# 182873     SE  SP         São Paulo    M  entre 31 a 40 anos       20/12/2019
# 182874     SE  SP         São Paulo    F  entre 31 a 40 anos       27/12/2019
# 182875     SE  SP         Rio Claro    M  entre 21 a 30 anos       27/12/2019
# 182876     S   PR             Turvo    F  entre 21 a 30 anos       26/12/2019
#
#         Tempo Resposta  Nome Fantasia  \
# 0                  2.0        Samsung
# 1                  1.0            NET
# 2                  5.0     Oi Celular
# 3                  4.0        Oi Fixo
# 4                  2.0        Oi Fixo
# ...                ...            ...
# 182872             3.0  Mercado Livre
# 182873             3.0            Tim
# 182874             3.0            Tim
# 182875             7.0            Tim
# 182876             2.0            Tim
#
#                                       Segmento de Mercado              Área  \
# 0       Fabricantes - Eletroeletrônicos,  Produtos de ...  Telecomunicações
# 1       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 2       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 3       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 4       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# ...                                                   ...               ...
# 182872   Empresas de Intermediação de Serviços / Negócios  Telecomunicações
# 182873  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182874  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182875  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182876  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
#
#         ...                 Situação Avaliação Reclamação Nota do Consumidor  \
# 0       ...      Finalizada avaliada        Não Resolvida                1.0
# 1       ...      Finalizada avaliada            Resolvida                5.0
# 2       ...      Finalizada avaliada            Resolvida                5.0
# 3       ...      Finalizada avaliada            Resolvida                5.0
# 4       ...      Finalizada avaliada            Resolvida                5.0
# ...     ...                      ...                  ...                ...
# 182872  ...      Finalizada avaliada            Resolvida                4.0
# 182873  ...      Finalizada avaliada        Não Resolvida                1.0
# 182874  ...      Finalizada avaliada            Resolvida                4.0
# 182875  ...      Finalizada avaliada            Resolvida                5.0
# 182876  ...  Finalizada não avaliada         Não Avaliada                NaN
#
#        Total ï»¿RegiÃ£o Faixa EtÃ¡ria Data FinalizaÃ§Ã£o Ãrea  SituaÃ§Ã£o  \
# 0          1        NaN           NaN                NaN   NaN         NaN
# 1          1        NaN           NaN                NaN   NaN         NaN
# 2          1        NaN           NaN                NaN   NaN         NaN
# 3          1        NaN           NaN                NaN   NaN         NaN
# 4          1        NaN           NaN                NaN   NaN         NaN
# ...      ...        ...           ...                ...   ...         ...
# 182872     1        NaN           NaN                NaN   NaN         NaN
# 182873     1        NaN           NaN                NaN   NaN         NaN
# 182874     1        NaN           NaN                NaN   NaN         NaN
# 182875     1        NaN           NaN                NaN   NaN         NaN
# 182876     1        NaN           NaN                NaN   NaN         NaN
#
#         AvaliaÃ§Ã£o ReclamaÃ§Ã£o
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 182872                       NaN
# 182873                       NaN
# 182874                       NaN
# 182875                       NaN
# 182876                       NaN
#
# [182877 rows x 26 columns]

# %%
df_tele = pd.get_dummies(df_tele, columns=['Sexo','Avaliação Reclamação','Como Comprou Contratou','Procurou Empresa','Respondida','Situação'])

# %%
df_tele
# Out:
#        Região  UF            Cidade        Faixa Etária Data Finalização  \
# 0          SE  SP         São Paulo  entre 31 a 40 anos       31/01/2019
# 1          SE  SP   Pindamonhangaba  entre 51 a 60 anos       26/01/2019
# 2          SE  SP         São Paulo  entre 31 a 40 anos       29/01/2019
# 3          SE  RJ         Queimados  entre 31 a 40 anos       31/01/2019
# 4          NE  PI          Parnaíba  entre 21 a 30 anos       24/01/2019
# ...       ...  ..               ...                 ...              ...
# 182872     S   PR  São José do Ivaí         até 20 anos       24/12/2019
# 182873     SE  SP         São Paulo  entre 31 a 40 anos       20/12/2019
# 182874     SE  SP         São Paulo  entre 31 a 40 anos       27/12/2019
# 182875     SE  SP         Rio Claro  entre 21 a 30 anos       27/12/2019
# 182876     S   PR             Turvo  entre 21 a 30 anos       26/12/2019
#
#         Tempo Resposta  Nome Fantasia  \
# 0                  2.0        Samsung
# 1                  1.0            NET
# 2                  5.0     Oi Celular
# 3                  4.0        Oi Fixo
# 4                  2.0        Oi Fixo
# ...                ...            ...
# 182872             3.0  Mercado Livre
# 182873             3.0            Tim
# 182874             3.0            Tim
# 182875             7.0            Tim
# 182876             2.0            Tim
#
#                                       Segmento de Mercado              Área  \
# 0       Fabricantes - Eletroeletrônicos,  Produtos de ...  Telecomunicações
# 1       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 2       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 3       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 4       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# ...                                                   ...               ...
# 182872   Empresas de Intermediação de Serviços / Negócios  Telecomunicações
# 182873  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182874  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182875  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182876  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
#
#                              Assunto  ...  \
# 0                             Tablet  ...
# 1       Pacote de Serviços ( Combo )  ...
# 2           Telefonia Móvel Pré-paga  ...
# 3                     Telefonia Fixa  ...
# 4                      Internet Fixa  ...
# ...                              ...  ...
# 182872              Aparelho celular  ...
# 182873                 Internet Fixa  ...
# 182874      Telefonia Móvel Pré-paga  ...
# 182875      Telefonia Móvel Pós-paga  ...
# 182876      Telefonia Móvel Pré-paga  ...
#
#        Como Comprou Contratou_Não comprei / contratei  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
# 182876                                              0
#
#        Como Comprou Contratou_SMS / Mensagem de texto  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
# 182876                                              0
#
#         Como Comprou Contratou_Stand, feiras e eventos  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 182872                                               0
# 182873                                               0
# 182874                                               0
# 182875                                               0
# 182876                                               0
#
#         Como Comprou Contratou_Telefone Procurou Empresa_N Procurou Empresa_S  \
# 0                                     0                  1                  0
# 1                                     0                  0                  1
# 2                                     1                  0                  1
# 3                                     0                  1                  0
# 4                                     0                  1                  0
# ...                                 ...                ...                ...
# 182872                                0                  0                  1
# 182873                                1                  0                  1
# 182874                                0                  0                  1
# 182875                                0                  1                  0
# 182876                                0                  1                  0
#
#        Respondida_N Respondida_S Situação_Finalizada avaliada  \
# 0                 0            1                            1
# 1                 0            1                            1
# 2                 0            1                            1
# 3                 0            1                            1
# 4                 0            1                            1
# ...             ...          ...                          ...
# 182872            0            1                            1
# 182873            0            1                            1
# 182874            0            1                            1
# 182875            0            1                            1
# 182876            0            1                            0
#
#        Situação_Finalizada não avaliada
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 182872                                0
# 182873                                0
# 182874                                0
# 182875                                0
# 182876                                1
#
# [182877 rows x 40 columns]

# %%
df_tele.drop(columns=['ï»¿RegiÃ£o', 'Faixa EtÃ¡ria','Data FinalizaÃ§Ã£o','Ãrea','SituaÃ§Ã£o','AvaliaÃ§Ã£o ReclamaÃ§Ã£o'])
# Out:
#        Região  UF            Cidade        Faixa Etária Data Finalização  \
# 0          SE  SP         São Paulo  entre 31 a 40 anos       31/01/2019
# 1          SE  SP   Pindamonhangaba  entre 51 a 60 anos       26/01/2019
# 2          SE  SP         São Paulo  entre 31 a 40 anos       29/01/2019
# 3          SE  RJ         Queimados  entre 31 a 40 anos       31/01/2019
# 4          NE  PI          Parnaíba  entre 21 a 30 anos       24/01/2019
# ...       ...  ..               ...                 ...              ...
# 182872     S   PR  São José do Ivaí         até 20 anos       24/12/2019
# 182873     SE  SP         São Paulo  entre 31 a 40 anos       20/12/2019
# 182874     SE  SP         São Paulo  entre 31 a 40 anos       27/12/2019
# 182875     SE  SP         Rio Claro  entre 21 a 30 anos       27/12/2019
# 182876     S   PR             Turvo  entre 21 a 30 anos       26/12/2019
#
#         Tempo Resposta  Nome Fantasia  \
# 0                  2.0        Samsung
# 1                  1.0            NET
# 2                  5.0     Oi Celular
# 3                  4.0        Oi Fixo
# 4                  2.0        Oi Fixo
# ...                ...            ...
# 182872             3.0  Mercado Livre
# 182873             3.0            Tim
# 182874             3.0            Tim
# 182875             7.0            Tim
# 182876             2.0            Tim
#
#                                       Segmento de Mercado              Área  \
# 0       Fabricantes - Eletroeletrônicos,  Produtos de ...  Telecomunicações
# 1       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 2       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 3       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 4       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# ...                                                   ...               ...
# 182872   Empresas de Intermediação de Serviços / Negócios  Telecomunicações
# 182873  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182874  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182875  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182876  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
#
#                              Assunto  ...  \
# 0                             Tablet  ...
# 1       Pacote de Serviços ( Combo )  ...
# 2           Telefonia Móvel Pré-paga  ...
# 3                     Telefonia Fixa  ...
# 4                      Internet Fixa  ...
# ...                              ...  ...
# 182872              Aparelho celular  ...
# 182873                 Internet Fixa  ...
# 182874      Telefonia Móvel Pré-paga  ...
# 182875      Telefonia Móvel Pós-paga  ...
# 182876      Telefonia Móvel Pré-paga  ...
#
#        Como Comprou Contratou_Não comprei / contratei  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
# 182876                                              0
#
#        Como Comprou Contratou_SMS / Mensagem de texto  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
# 182876                                              0
#
#         Como Comprou Contratou_Stand, feiras e eventos  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 182872                                               0
# 182873                                               0
# 182874                                               0
# 182875                                               0
# 182876                                               0
#
#         Como Comprou Contratou_Telefone  Procurou Empresa_N  \
# 0                                     0                   1
# 1                                     0                   0
# 2                                     1                   0
# 3                                     0                   1
# 4                                     0                   1
# ...                                 ...                 ...
# 182872                                0                   0
# 182873                                1                   0
# 182874                                0                   0
# 182875                                0                   1
# 182876                                0                   1
#
#         Procurou Empresa_S  Respondida_N  Respondida_S  \
# 0                        0             0             1
# 1                        1             0             1
# 2                        1             0             1
# 3                        0             0             1
# 4                        0             0             1
# ...                    ...           ...           ...
# 182872                   1             0             1
# 182873                   1             0             1
# 182874                   1             0             1
# 182875                   0             0             1
# 182876                   0             0             1
#
#         Situação_Finalizada avaliada  Situação_Finalizada não avaliada
# 0                                  1                                 0
# 1                                  1                                 0
# 2                                  1                                 0
# 3                                  1                                 0
# 4                                  1                                 0
# ...                              ...                               ...
# 182872                             1                                 0
# 182873                             1                                 0
# 182874                             1                                 0
# 182875                             1                                 0
# 182876                             0                                 1
#
# [182877 rows x 34 columns]

# %%
df_tele.dropna(subset=['Nota do Consumidor'], inplace=True)

# %%
print(df_tele.columns)
# Out:
# Index(['Região', 'UF', 'Cidade', 'Faixa Etária', 'Data Finalização',
#        'Tempo Resposta', 'Nome Fantasia', 'Segmento de Mercado', 'Área',
#        'Assunto', 'Grupo Problema', 'Problema', 'Nota do Consumidor', 'Total',
#        'ï»¿RegiÃ£o', 'Faixa EtÃ¡ria', 'Data FinalizaÃ§Ã£o', 'Ãrea',
#        'SituaÃ§Ã£o', 'AvaliaÃ§Ã£o ReclamaÃ§Ã£o', 'Sexo_F', 'Sexo_M',
#        'Avaliação Reclamação_Não Avaliada',
#        'Avaliação Reclamação_Não Resolvida', 'Avaliação Reclamação_Resolvida',
#        'Como Comprou Contratou_Catálogo', 'Como Comprou Contratou_Domicílio',
#        'Como Comprou Contratou_Ganhei de presente',
#        'Como Comprou Contratou_Internet', 'Como Comprou Contratou_Loja física',
#        'Como Comprou Contratou_Não comprei / contratei',
#        'Como Comprou Contratou_SMS / Mensagem de texto',
#        'Como Comprou Contratou_Stand, feiras e eventos',
#        'Como Comprou Contratou_Telefone', 'Procurou Empresa_N',
#        'Procurou Empresa_S', 'Respondida_N', 'Respondida_S',
#        'Situação_Finalizada avaliada', 'Situação_Finalizada não avaliada'],
#       dtype='object')

# %%
df_tele.drop(columns=['ï»¿RegiÃ£o', 'Faixa EtÃ¡ria', 'Data FinalizaÃ§Ã£o', 'Ãrea','SituaÃ§Ã£o', 'AvaliaÃ§Ã£o ReclamaÃ§Ã£o'])
# Out:
#        Região  UF            Cidade        Faixa Etária Data Finalização  \
# 0          SE  SP         São Paulo  entre 31 a 40 anos       31/01/2019
# 1          SE  SP   Pindamonhangaba  entre 51 a 60 anos       26/01/2019
# 2          SE  SP         São Paulo  entre 31 a 40 anos       29/01/2019
# 3          SE  RJ         Queimados  entre 31 a 40 anos       31/01/2019
# 4          NE  PI          Parnaíba  entre 21 a 30 anos       24/01/2019
# ...       ...  ..               ...                 ...              ...
# 182871     S   RS            Itaqui  entre 31 a 40 anos       20/12/2019
# 182872     S   PR  São José do Ivaí         até 20 anos       24/12/2019
# 182873     SE  SP         São Paulo  entre 31 a 40 anos       20/12/2019
# 182874     SE  SP         São Paulo  entre 31 a 40 anos       27/12/2019
# 182875     SE  SP         Rio Claro  entre 21 a 30 anos       27/12/2019
#
#         Tempo Resposta            Nome Fantasia  \
# 0                  2.0                  Samsung
# 1                  1.0                      NET
# 2                  5.0               Oi Celular
# 3                  4.0                  Oi Fixo
# 4                  2.0                  Oi Fixo
# ...                ...                      ...
# 182871             3.0  Vivo - Telefônica (GVT)
# 182872             3.0            Mercado Livre
# 182873             3.0                      Tim
# 182874             3.0                      Tim
# 182875             7.0                      Tim
#
#                                       Segmento de Mercado              Área  \
# 0       Fabricantes - Eletroeletrônicos,  Produtos de ...  Telecomunicações
# 1       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 2       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 3       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 4       Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# ...                                                   ...               ...
# 182871  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182872   Empresas de Intermediação de Serviços / Negócios  Telecomunicações
# 182873  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182874  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
# 182875  Operadoras de Telecomunicações (Telefonia, Int...  Telecomunicações
#
#                              Assunto  ...  \
# 0                             Tablet  ...
# 1       Pacote de Serviços ( Combo )  ...
# 2           Telefonia Móvel Pré-paga  ...
# 3                     Telefonia Fixa  ...
# 4                      Internet Fixa  ...
# ...                              ...  ...
# 182871      Telefonia Móvel Pré-paga  ...
# 182872              Aparelho celular  ...
# 182873                 Internet Fixa  ...
# 182874      Telefonia Móvel Pré-paga  ...
# 182875      Telefonia Móvel Pós-paga  ...
#
#        Como Comprou Contratou_Não comprei / contratei  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182871                                              0
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
#
#        Como Comprou Contratou_SMS / Mensagem de texto  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ...                                               ...
# 182871                                              0
# 182872                                              0
# 182873                                              0
# 182874                                              0
# 182875                                              0
#
#         Como Comprou Contratou_Stand, feiras e eventos  \
# 0                                                    0
# 1                                                    0
# 2                                                    0
# 3                                                    0
# 4                                                    0
# ...                                                ...
# 182871                                               0
# 182872                                               0
# 182873                                               0
# 182874                                               0
# 182875                                               0
#
#         Como Comprou Contratou_Telefone  Procurou Empresa_N  \
# 0                                     0                   1
# 1                                     0                   0
# 2                                     1                   0
# 3                                     0                   1
# 4                                     0                   1
# ...                                 ...                 ...
# 182871                                1                   1
# 182872                                0                   0
# 182873                                1                   0
# 182874                                0                   0
# 182875                                0                   1
#
#         Procurou Empresa_S  Respondida_N  Respondida_S  \
# 0                        0             0             1
# 1                        1             0             1
# 2                        1             0             1
# 3                        0             0             1
# 4                        0             0             1
# ...                    ...           ...           ...
# 182871                   0             0             1
# 182872                   1             0             1
# 182873                   1             0             1
# 182874                   1             0             1
# 182875                   0             0             1
#
#         Situação_Finalizada avaliada  Situação_Finalizada não avaliada
# 0                                  1                                 0
# 1                                  1                                 0
# 2                                  1                                 0
# 3                                  1                                 0
# 4                                  1                                 0
# ...                              ...                               ...
# 182871                             1                                 0
# 182872                             1                                 0
# 182873                             1                                 0
# 182874                             1                                 0
# 182875                             1                                 0
#
# [126301 rows x 34 columns]

# %%
print(df_tele.columns)
# Out:
# Index(['Região', 'UF', 'Cidade', 'Faixa Etária', 'Data Finalização',
#        'Tempo Resposta', 'Nome Fantasia', 'Segmento de Mercado', 'Área',
#        'Assunto', 'Grupo Problema', 'Problema', 'Nota do Consumidor', 'Total',
#        'ï»¿RegiÃ£o', 'Faixa EtÃ¡ria', 'Data FinalizaÃ§Ã£o', 'Ãrea',
#        'SituaÃ§Ã£o', 'AvaliaÃ§Ã£o ReclamaÃ§Ã£o', 'Sexo_F', 'Sexo_M',
#        'Avaliação Reclamação_Não Avaliada',
#        'Avaliação Reclamação_Não Resolvida', 'Avaliação Reclamação_Resolvida',
#        'Como Comprou Contratou_Catálogo', 'Como Comprou Contratou_Domicílio',
#        'Como Comprou Contratou_Ganhei de presente',
#        'Como Comprou Contratou_Internet', 'Como Comprou Contratou_Loja física',
#        'Como Comprou Contratou_Não comprei / contratei',
#        'Como Comprou Contratou_SMS / Mensagem de texto',
#        'Como Comprou Contratou_Stand, feiras e eventos',
#        'Como Comprou Contratou_Telefone', 'Procurou Empresa_N',
#        'Procurou Empresa_S', 'Respondida_N', 'Respondida_S',
#        'Situação_Finalizada avaliada', 'Situação_Finalizada não avaliada'],
#       dtype='object')

# %%
df_tele.dropna(subset=['Sexo_F', 'Sexo_M', 'Tempo Resposta', 'Avaliação Reclamação_Não Avaliada','Avaliação Reclamação_Não Resolvida','Como Comprou Contratou_Catálogo', 'Como Comprou Contratou_Domicílio','Como Comprou Contratou_Ganhei de presente','Como Comprou Contratou_Internet', 'Como Comprou Contratou_Loja física','Como Comprou Contratou_Não comprei / contratei','Como Comprou Contratou_SMS / Mensagem de texto','Como Comprou Contratou_Stand, feiras e eventos','Como Comprou Contratou_Telefone','Procurou Empresa_N','Procurou Empresa_S','Situação_Finalizada avaliada', 'Situação_Finalizada não avaliada','Nota do Consumidor'],inplace=True)

# %%
chosenColumns = ['Sexo_F', 'Sexo_M', 'Tempo Resposta', 'Avaliação Reclamação_Não Avaliada','Avaliação Reclamação_Não Resolvida','Como Comprou Contratou_Catálogo', 'Como Comprou Contratou_Domicílio','Como Comprou Contratou_Ganhei de presente','Como Comprou Contratou_Internet', 'Como Comprou Contratou_Loja física','Como Comprou Contratou_Não comprei / contratei','Como Comprou Contratou_SMS / Mensagem de texto','Como Comprou Contratou_Stand, feiras e eventos','Como Comprou Contratou_Telefone','Procurou Empresa_N','Procurou Empresa_S','Situação_Finalizada avaliada', 'Situação_Finalizada não avaliada','Nota do Consumidor']

# %%
myX = df_tele[chosenColumns].values

# %%
chosenOutcomes = ['Respondida_N','Respondida_S']

# %%
myY = df_tele[chosenOutcomes].values

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %%
xTrain, xTest, yTrain, yTest = train_test_split(myX, myY, train_size=0.7, random_state=3)
testSize = yTest.shape[0]

# %%
np.where(np.isnan(myX))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
np.where(np.isnan(myY))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
# Random Forest

rf = RandomForestClassifier(max_depth=4, n_estimators=100,bootstrap=True)
rf.fit(xTrain, yTrain.ravel())
yPredRF = rf.predict(xTest) # predicting test data
yPredRFroc = rf.predict_proba(xTest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-20d93723ceca> in <module>
#       2
#       3 rf = RandomForestClassifier(max_depth=4, n_estimators=100,bootstrap=True)
# ----> 4 rf.fit(xTrain, yTrain.ravel())
#       5 yPredRF = rf.predict(xTest) # predicting test data
#       6 yPredRFroc = rf.predict_proba(xTest)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     381                     verbose=self.verbose, class_weight=self.class_weight,
#     382                     n_samples_bootstrap=n_samples_bootstrap)
# --> 383                 for i, t in enumerate(trees))
#     384
#     385             # Collect newly grown trees
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1002             # remaining jobs.
#    1003             self._iterating = False
# -> 1004             if self.dispatch_one_batch(iterator):
#    1005                 self._iterating = self._original_iterator is not None
#    1006
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     833                 return False
#     834             else:
# --> 835                 self._dispatch(tasks)
#     836                 return True
#     837
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     752         with self._lock:
#     753             job_idx = len(self._jobs)
# --> 754             job = self._backend.apply_async(batch, callback=cb)
#     755             # A job can complete so quickly than its callback is
#     756             # called before we get here, causing self._jobs to
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     207     def apply_async(self, func, callback=None):
#     208         """Schedule a func to be run"""
# --> 209         result = ImmediateResult(func)
#     210         if callback:
#     211             callback(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     588         # Don't delay the application, to avoid keeping the input
#     589         # arguments in memory
# --> 590         self.results = batch()
#     591
#     592     def get(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     163             curr_sample_weight *= compute_sample_weight('balanced', y, indices)
#     164
# --> 165         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     166     else:
#     167         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     875             sample_weight=sample_weight,
#     876             check_input=check_input,
# --> 877             X_idx_sorted=X_idx_sorted)
#     878         return self
#     879
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     263         if len(y) != n_samples:
#     264             raise ValueError("Number of labels=%d does not match "
# --> 265                              "number of samples=%d" % (len(y), n_samples))
#     266         if not 0 <= self.min_weight_fraction_leaf <= 0.5:
#     267             raise ValueError("min_weight_fraction_leaf must in [0, 0.5]")
#
# ValueError: Number of labels=176560 does not match number of samples=88280

# %%
iterable = ((yPredRF[i] != yTest[i]) for i in range(0, testSize))
errorRF = np.sum(np.fromiter(iterable,int))
errorRFPCT = int(100*errorRF/testSize)
hitRateRFPCT = 100 - errorRFPCT

# %%
print("----------Random Forest Classfier----------")
print(int(errorRF), "misclassified data out of", testSize)
print("Error PCT: ",errorRFPCT,'%')
print("Hit Rate:  ",hitRateRFPCT,'%')
# Out:
# ----------Random Forest Classfier----------
# 0 misclassified data out of 37835
# Error PCT:  0 %
# Hit Rate:   100 %

# %%
fpr, tpr, thresh = roc_curve(yTest.ravel(), yPredRFroc.ravel())
#fpr, tpr, thresh = roc_curve(yTest.ravel(), yPredRF.ravel())
rocAuc = auc(fpr, tpr)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py:808: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)

# %%
plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % rocAuc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.01])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# Gradient Boosting

gb = GradientBoostingClassifier(max_depth=4, n_estimators=100, learning_rate=0.1)
gb.fit(xTrain, yTrain.ravel())
yPredGB = gb.predict(xTest) # predicting test data
yPredGBroc = gb.predict_proba(xTest)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-62a4637e9206> in <module>
#       2
#       3 gb = GradientBoostingClassifier(max_depth=4, n_estimators=100, learning_rate=0.1)
# ----> 4 gb.fit(xTrain, yTrain.ravel())
#       5 yPredGB = gb.predict(xTest) # predicting test data
#       6 yPredGBroc = gb.predict_proba(xTest)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in fit(self, X, y, sample_weight, monitor)
#    1453         y = check_array(y, accept_sparse='csc', ensure_2d=False, dtype=None)
#    1454         y = column_or_1d(y, warn=True)
# -> 1455         y = self._validate_y(y, sample_weight)
#    1456
#    1457         if self.n_iter_no_change is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py in _validate_y(self, y, sample_weight)
#    2095                              "trimmed classes with zero weights, while a "
#    2096                              "minimum of 2 classes are required."
# -> 2097                              % n_trim_classes)
#    2098         self.n_classes_ = len(self.classes_)
#    2099         return y
#
# ValueError: y contains 1 class after sample_weight trimmed classes with zero weights, while a minimum of 2 classes are required.
